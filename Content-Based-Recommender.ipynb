# %% [markdown]
# # Import libraries and load data

# %%
import pandas as pd
import numpy as np
from search_movie_data import *

# %%
movies = pd.read_csv("movies_preprocessed.csv")
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9556 entries, 0 to 9555
# Data columns (total 30 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   movieId             9556 non-null   int64
#  1   title               9556 non-null   object
#  2   genres              9556 non-null   object
#  3   Adventure           9556 non-null   int64
#  4   Horror              9556 non-null   int64
#  5   Thriller            9556 non-null   int64
#  6   Crime               9556 non-null   int64
#  7   Musical             9556 non-null   int64
#  8   Documentary         9556 non-null   int64
#  9   Mystery             9556 non-null   int64
#  10  Children            9556 non-null   int64
#  11  Sci-Fi              9556 non-null   int64
#  12  Western             9556 non-null   int64
#  13  Fantasy             9556 non-null   int64
#  14  Film-Noir           9556 non-null   int64
#  15  Animation           9556 non-null   int64
#  16  Action              9556 non-null   int64
#  17  Romance             9556 non-null   int64
#  18  War                 9556 non-null   int64
#  19  (no genres listed)  9556 non-null   int64
#  20  IMAX                9556 non-null   int64
#  21  Drama               9556 non-null   int64
#  22  Comedy              9556 non-null   int64
#  23  mean_rating         9556 non-null   float64
#  24  num_ratings         9556 non-null   int64
#  25  weighted_rating     9556 non-null   float64
#  26  tag_soup            9556 non-null   object
#  27  year                9556 non-null   int64
#  28  title_clean         9556 non-null   object
#  29  relevant_tag_soup   8643 non-null   object
# dtypes: float64(2), int64(23), object(5)
# memory usage: 2.2+ MB

# %% [markdown]
# The only column with any missing values is relevant_tag_soup, which contains the most relevant tags according to the genome tag data. So, if I want to search by similarity between relevant_tag_soup values, I'll have to remove the NA values.
#
# To look at the relevance scores that led to the relevant_tag_soup, I can look at the data saved in `tag_genome_preprocessed.csv`.

# %%
genome_tags = pd.read_csv('tag_genome_preprocessed.csv')
genome_tags.head()
# Out:
#    movieId                        title                  title_clean  year  \
# 0        1                    Toy Story                    toy story  1995
# 1        2                      Jumanji                      jumanji  1995
# 2        3             Grumpier Old Men             grumpier old men  1995
# 3        4            Waiting to Exhale            waiting to exhale  1995
# 4        5  Father of the Bride Part II  father of the bride part ii  1995
#
#        007  007 (series)  18th century    1920s    1930s    1950s  ...  \
# 0  0.02900       0.02375       0.05425  0.06875  0.16000  0.19525  ...
# 1  0.03625       0.03625       0.08275  0.08175  0.10200  0.06900  ...
# 2  0.04150       0.04950       0.03000  0.09525  0.04525  0.05925  ...
# 3  0.03350       0.03675       0.04275  0.02625  0.05250  0.03025  ...
# 4  0.04050       0.05175       0.03600  0.04625  0.05500  0.08000  ...
#
#    world war i  world war ii  writer's life  writers  writing    wuxia  \
# 0      0.02250       0.04075        0.03175  0.12950  0.04550  0.02000
# 1      0.02050       0.01650        0.02450  0.13050  0.02700  0.01825
# 2      0.02375       0.03550        0.02125  0.12775  0.03250  0.01625
# 3      0.03275       0.02125        0.03675  0.15925  0.05225  0.01500
# 4      0.02625       0.02050        0.02125  0.17725  0.02050  0.01500
#
#       wwii   zombie  zombies  \
# 0  0.03850  0.09125  0.02225
# 1  0.01225  0.09925  0.01850
# 2  0.02125  0.09525  0.01750
# 3  0.01600  0.09175  0.01500
# 4  0.01550  0.08875  0.01575
#
#                                    relevant_tag_soup
# 0  toys computeranimation pixaranimation animatio...
# 1  adventure children fantasy kids jungle special...
# 2          sequel goodsequel sequels comedy original
# 3              women chickflick girliemovie romantic
# 4  goodsequel sequel sequels pregnancy fatherdaug...
#
# [5 rows x 1133 columns]

# %% [markdown]
# The relevant_tag_soup contains the tags that have a relevance score of at least 0.75.

# %% [markdown]
# # Search for movie by title
#
# `search_title` is an important function for the later functions that find similar movies to a given title.
#
# Before searching for matches, title is converted to lowercase and all punctuation is removed. This allows for more fool-proof matching before resorting to fuzzy string matching (see below).

# %% [markdown]
# If there is one perfect match, return that movie's movieId.

# %%
search_title(movies, 'sixteen candles')
# Out:
# 2144

# %% [markdown]
# If there are multiple perfect matches, ask user to select one and then return movieId.

# %%
search_title(movies, 'father of the bride')
# Out:
# More than one movie with matching title
#
# 1: Father of the Bride (1950)
# 2: Father of the Bride (1991)
#
# Please select movie number, or enter -1 to exit: 2
# 6944

# %% [markdown]
# If there are no perfect matches (e.g., typos, alternate spellings), perform fuzzy string matching by computing Levenshtein difference ratio between input title and all titles in dataframe, returning closest matches.

# %%
search_title(movies, 'findingnemo')
# Out:
# Cannot find that title, looking for similar titles...
#
# One possible match found. Is this the title you want?
#
# Finding Nemo (2003)
# Enter y or n: y
# 6377

# %%
search_title(movies, 'fast furious')
# Out:
# Cannot find that title, looking for similar titles...
#
# More than one potential match found
#
# 1: Fast and the Furious, The (2001)
# 2: The Fate of the Furious (2017)
#
# Please select movie number, or enter -1 to exit: 1
# 4369

# %% [markdown]
# # Get most relevant tags for each movie
#
# `get_most_relevant_tags` returns the tags with the highest relevance score for a given movie.
# - Returns a series where the index is the name of the tag and the value is the relevance score (0-1)
# - Default number of tags returned is 10, but `num_tags` can be passed as an argument

# %%
get_most_relevant_tags(genome_tags, 'finding nemo', num_tags=15)
# Out:
# oscar (best animated feature)    0.99825
# pixar animation                  0.99550
# computer animation               0.99350
# short-term memory loss           0.99225
# animation                        0.99050
# children                         0.98075
# kids and family                  0.97850
# kids                             0.97800
# fish                             0.97625
# cartoon                          0.97175
# animated                         0.97125
# pixar                            0.97025
# animals                          0.93500
# story                            0.93150
# heartwarming                     0.92850
# Name: 4317, dtype: float64

# %% [markdown]
# `get_relevant_tag_soup` returns a string of space-separated tags with a relevance score of 0.75 or greater.

# %%
get_relevant_tag_soup(genome_tags, 'finding nemo')
# Out:
# 'oscarbestanimatedfeature pixaranimation computeranimation shorttermmemoryloss animation children kidsandfamily kids fish cartoon animated pixar animals story heartwarming cute imdbtop250 talkinganimals toys family touching disney singlefather oscarwinner original friendship storytelling adventure fun good childhood cute entertaining great funny greatmovie visuallystunning memoryloss clever comedy shark disneyanimatedfeature feelgoodmovie underwater'

# %% [markdown]
# # Find similar movies to a given title
#
# `get_similar_movies` returns a dataframe of movies that are most similar to a title passed as input.
# `get_similar_titles` returns a series of titles associated with output of `get_similar_movies`.
#
# Optional parameters determine how `get_similar_movies` operates. These same parameters can be passed to `get_similar_titles`, which will then be passed to its implementation of `get_similar_movies`. Optional parameters are:
# - `how`: method of finding similarity
#     - `'tag_soup'`: find similar movies based on list of user-assigned tags or relevant genome tags (default)
#     - `'tag_relevance'`: find similar movies based on relevance scores assigned to each tag
# - `field`: column of dataframe to compute similarity between movies (default = 'tag_soup') (only applies when `how='tag_soup'`
# - `num_movies`: number of similar movies to return (default = 10)
#
# ## Find similar movies based on list of user-assigned tags or relevant genome tags
#
# Default behavior of `get_similar_titles` is to call `get_similar_tag_soup`.
# - Tokenizes words in string of tag soup
# - Computes cosine similarity between each movie's tags and the target movie's tags.
# - Returns titles of movies with highest cosine similarity.

# %%
get_similar_titles(movies, 'finding nemo')
# Out:
# 0                 Toy Story
# 1739          Bug's Life, A
# 2334            Toy Story 2
# 3533         Monsters, Inc.
# 3709                Ice Age
# 6154                   Cars
# 6346            Ratatouille
# 7291            Toy Story 3
# 8114    Monsters University
# 9130           Finding Dory
# Name: title, dtype: object

# %% [markdown]
# Because there are some movies with null values for relevant_tag_soup, null rows need to be dropped before using relevant_tag_soup as the source of similarity between movies.

# %%
get_similar_titles(movies.dropna(), 'finding nemo', field='relevant_tag_soup')
# Out:
# 0            Toy Story
# 1716     Bug's Life, A
# 2306       Toy Story 2
# 3496    Monsters, Inc.
# 3668           Ice Age
# 5808    Chicken Little
# 6133       Ratatouille
# 6729                Up
# 7000       Toy Story 3
# 8416      Finding Dory
# Name: title, dtype: object

# %% [markdown]
# `relevant_tag_soup` gives similar results to `tag_soup`, so it's likely better to use `tag_soup` because there are no missing values.
#
# It is also possible to search for similar titles within a subset of the data. However, the input title must be part of filtered data (i.e., must have filtered tags or genres).

# %%
# First search without filtering
get_similar_movies(movies, 'my big fat greek wedding')
# Out:
#       movieId                           title                genres  \
# 311       357     Four Weddings and a Funeral        Comedy|Romance
# 1628     2195                      Dirty Work                Comedy
# 1755     2371                          Fletch  Comedy|Crime|Mystery
# 2690     3646               Big Momma's House                Comedy
# 3727     5250                      Stir Crazy                Comedy
# 4470     6687              My Boss's Daughter        Comedy|Romance
# 4598     6944             Father of the Bride                Comedy
# 5174     8531                    White Chicks   Action|Comedy|Crime
# 5904    34530  Deuce Bigalow: European Gigolo                Comedy
# 8818   135861                           Ted 2                Comedy
#
#       Adventure  Horror  Thriller  Crime  Musical  Documentary  Mystery  ...  \
# 311           0       0         0      0        0            0        0  ...
# 1628          0       0         0      0        0            0        0  ...
# 1755          0       0         0      1        0            0        1  ...
# 2690          0       0         0      0        0            0        0  ...
# 3727          0       0         0      0        0            0        0  ...
# 4470          0       0         0      0        0            0        0  ...
# 4598          0       0         0      0        0            0        0  ...
# 5174          0       0         0      1        0            0        0  ...
# 5904          0       0         0      0        0            0        0  ...
# 8818          0       0         0      0        0            0        0  ...
#
#       IMAX  Drama  Comedy  mean_rating  num_ratings  weighted_rating  \
# 311      0      0       1     0.728926        30236         0.728776
# 1628     0      0       1     0.615865         1248         0.628327
# 1755     0      0       1     0.685466         7582         0.685996
# 2690     0      0       1     0.473999         3473         0.486637
# 3727     0      0       1     0.668531          715         0.676741
# 4470     0      0       1     0.479545          528         0.541783
# 4598     0      0       1     0.667226         3518         0.669316
# 5174     0      0       1     0.479799         2193         0.498712
# 5904     0      0       1     0.427753          890         0.478824
# 8818     0      0       1     0.602570         1362         0.615824
#
#                                                tag_soup  year  \
# 311   british hughgrant witty british donotlikehughg...  1994
# 1628  normmacdonald comedy comedy christophermcdonal...  1998
# 1755  comedy comedy comedy comedy comedy comedy mema...  1985
# 2690  comedy comedy comedy comedy disguise fbiagent ...  2000
# 3727  comedy comedy comedy genewilder richardpryor c...  1980
# 4470                    owned comedy funny comedy funny  2003
# 4598  comedy stevemartin itaege wedding remake weddi...  1991
# 5174  crossdressing whiteface comedy comedy comedy c...  2004
# 5904  amsterdam comedy comedy comedy comedy goldenra...  2005
# 8818  stupid comedy funny ted comedy juvenile unnece...  2015
#
#                         title_clean  \
# 311     four weddings and a funeral
# 1628                     dirty work
# 1755                         fletch
# 2690               big mommas house
# 3727                     stir crazy
# 4470              my bosss daughter
# 4598            father of the bride
# 5174                   white chicks
# 5904  deuce bigalow european gigolo
# 8818                          ted 2
#
#                                       relevant_tag_soup
# 311   romanticcomedy relationships britishcomedy chi...
# 1628  comedy funny saturdaynightlive chase funniestm...
# 1755  chase comedy investigation quotable saturdayni...
# 2690   comedy funny undercovercop predictable veryfunny
# 3727         comedy prisonescape funny prison veryfunny
# 4470  comedy stupidity dumbbutfunny stupid teenmovie...
# 4598  wedding comedy remake family girliemovie roman...
# 5174  comedy dumbbutfunny dumb crossdressing sillyfu...
# 5904  stupidashell comedy funny stupid predictable p...
# 8818  comedy weed sequel sequels crudehumor funny du...
#
# [10 rows x 30 columns]

# %%
# Now search just rom-coms
romcoms = filter_genre(movies, ['Romance', 'Comedy'])
get_similar_movies(romcoms, 'my big fat greek wedding')
# Out:
#      movieId                          title                genres  Adventure  \
# 33       357    Four Weddings and a Funeral        Comedy|Romance          0
# 269     4246          Bridget Jones's Diary  Comedy|Drama|Romance          0
# 282     4447                 Legally Blonde        Comedy|Romance          0
# 413     6687             My Boss's Daughter        Comedy|Romance          0
# 455     7255  Win a Date with Tad Hamilton!        Comedy|Romance          0
# 567    34162               Wedding Crashers        Comedy|Romance          0
# 747    90576            What's Your Number?        Comedy|Romance          0
# 821   118814                Playing It Cool        Comedy|Romance          0
# 831   130978               Love and Pigeons        Comedy|Romance          0
# 849   147196                      The Girls        Comedy|Romance          0
#
#      Horror  Thriller  Crime  Musical  Documentary  Mystery  ...  IMAX  Drama  \
# 33        0         0      0        0            0        0  ...     0      0
# 269       0         0      0        0            0        0  ...     0      1
# 282       0         0      0        0            0        0  ...     0      0
# 413       0         0      0        0            0        0  ...     0      0
# 455       0         0      0        0            0        0  ...     0      0
# 567       0         0      0        0            0        0  ...     0      0
# 747       0         0      0        0            0        0  ...     0      0
# 821       0         0      0        0            0        0  ...     0      0
# 831       0         0      0        0            0        0  ...     0      0
# 849       0         0      0        0            0        0  ...     0      0
#
#      Comedy  mean_rating  num_ratings  weighted_rating  \
# 33        1     0.728926        30236         0.728776
# 269       1     0.680338        16667         0.680644
# 282       1     0.631435        13447         0.632529
# 413       1     0.479545          528         0.541783
# 455       1     0.567961          927         0.592474
# 567       1     0.688274        11470         0.688579
# 747       1     0.643428          601         0.659073
# 821       1     0.634091           88         0.684090
# 831       1     0.773950          119         0.731404
# 849       1     0.811429           70         0.733399
#
#                                               tag_soup  year  \
# 33   british hughgrant witty british donotlikehughg...  1994
# 269  romanticcomedy basedonabook british comedy dra...  2001
# 282  comedy okayonce absurd feminism feminist sense...  2001
# 413                    owned comedy funny comedy funny  2003
# 455  onedimensionalcharacters sexist joshduhamel ka...  2004
# 567  christopherwalken nuditytopless owenwilson ste...  2005
# 747  chickflick romance chickflick romance basedonn...  2011
# 821  comedy romance romanticcomedy whimsical engage...  2014
# 831  comedy romance sovietrussia vladimirmenshov pi...  1985
# 849                   comedy romance sentimentale ussr  1961
#
#                       title_clean  \
# 33    four weddings and a funeral
# 269          bridget joness diary
# 282                legally blonde
# 413             my bosss daughter
# 455  win a date with tad hamilton
# 567              wedding crashers
# 747             whats your number
# 821               playing it cool
# 831              love and pigeons
# 849                         girls
#
#                                      relevant_tag_soup
# 33   romanticcomedy relationships britishcomedy chi...
# 269  girliemovie chickflick romanticcomedy adaptedf...
# 282  girliemovie chickflick comedy cute funmovie ro...
# 413  comedy stupidity dumbbutfunny stupid teenmovie...
# 455  romanticcomedy girliemovie chickflick romantic...
# 567  comedy romanticcomedy wedding funny veryfunny ...
# 747  chickflick romanticcomedy girliemovie comedy r...
# 821  romanticcomedy romantic love lovestory relatio...
# 831                               russian storytelling
# 849  love romanticcomedy lovestory excellentscript ...
#
# [10 rows x 30 columns]

# %% [markdown]
# ## Find similar movies based on relevance scores assigned to each tag
#
# When parameter `how='tag_relevance'` is passed to `get_similar_titles`, it calls `get_similar_tag_relevance`.
#
# - Computes cosine similarity between relevance scores assigned to each movie and the scores assigned to the target movie.
# - Returns titles of movies with highest cosine similarity.

# %%
get_similar_titles(genome_tags, 'finding dory', how='tag_relevance')
# Out:
# 1739                          Bug's Life, A
# 2334                            Toy Story 2
# 3709                                Ice Age
# 6091                Ice Age 2: The Meltdown
# 7291                            Toy Story 3
# 7838                                  Brave
# 8114                    Monsters University
# 8124                        Despicable Me 2
# 8196    Cloudy with a Chance of Meatballs 2
# 8823                      The Good Dinosaur
# Name: title, dtype: object

# %% [markdown]
# # Compute top-rated movies similar to a given movie
#
# First, get list of similar movies.

# %%
similar_movies_genome = get_similar_movies(genome_tags, 'sixteen candles', how='tag_relevance', num_movies=20)

# %% [markdown]
# Slice rows of movies dataframe with corresponding movieId.

# %%
similar_movies = movies[movies['movieId'].isin(similar_movies_genome['movieId'])]

# %% [markdown]
# Get list of highest-rated movies in dataframe.

# %%
highest_rated(similar_movies, num_movies=8)
# Out:
# 1429           Breakfast Club, The
# 1653               Say Anything...
# 942             Better Off Dead...
# 7351                        Easy A
# 4444               Sure Thing, The
# 4895                    Mean Girls
# 975         Some Kind of Wonderful
# 1922    10 Things I Hate About You
# Name: title, dtype: object
